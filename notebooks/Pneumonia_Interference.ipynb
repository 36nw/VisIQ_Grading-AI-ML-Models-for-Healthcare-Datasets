# %% [markdown]
# ## Read Data

# %%
import pandas as pd

# Excel file path
file_path = 'C:/Users/muge/Dropbox/GMU/DAEN 690/Data/DAEN_690_Inference_XRay.xlsx'

# Dictionary to store DataFrames
dfs = {}

# List of sheet names
sheet_names = [
    'InceptionV3_20_1000',
    'InceptionV3_50_1000',
    'ResNet50_20_1000',
    'ResNet50_50_1000',
    'ResNet18_20_1000',
    'ResNet18_50_1000',
    'InceptionV3_20_500',
    'InceptionV3_50_500',
    'ResNet50_20_500',
    'ResNet50_50_500',
    'ResNet18_20_500',
    'ResNet18_50_500',
    'InceptionV3_20_250',
    'InceptionV3_50_250',
    'ResNet50_20_250',
    'ResNet50_50_250',
    'ResNet18_20_250',
    'ResNet18_50_250',
   ]

# Read each sheet into a DataFrame
for sheet_name in sheet_names:
    df = pd.read_excel(file_path, sheet_name=sheet_name)
    dfs[sheet_name] = df

# Access each DataFrame by sheet name
for sheet_name, df in dfs.items():
    print(f"Data from sheet '{sheet_name}':")
    #print(df)
# Out:
# Data from sheet 'InceptionV3_20_1000':
# Data from sheet 'InceptionV3_50_1000':
# Data from sheet 'ResNet50_20_1000':
# Data from sheet 'ResNet50_50_1000':
# Data from sheet 'ResNet18_20_1000':
# Data from sheet 'ResNet18_50_1000':
# Data from sheet 'InceptionV3_20_500':
# Data from sheet 'InceptionV3_50_500':
# Data from sheet 'ResNet50_20_500':
# Data from sheet 'ResNet50_50_500':
# Data from sheet 'ResNet18_20_500':
# Data from sheet 'ResNet18_50_500':
# Data from sheet 'InceptionV3_20_250':
# Data from sheet 'InceptionV3_50_250':
# Data from sheet 'ResNet50_20_250':
# Data from sheet 'ResNet50_50_250':
# Data from sheet 'ResNet18_20_250':
# Data from sheet 'ResNet18_50_250':

# %%
# Read all sheets into a list of DataFrames
dfs = [pd.read_excel(file_path, sheet_name=sheet_name) for sheet_name in sheet_names]

# Concatenate all DataFrames vertically
merged_df = pd.concat(dfs, ignore_index=True)

# Display the merged DataFrame
# print(merged_df)

# %% [markdown]
# ## Explore Data

# %% [markdown]
# #### Check Data Types

# %%
print("Columns:")
print(merged_df.columns)

print("\nData Types:")
print(merged_df.dtypes)
# Out:
# Columns:
# Index(['MODEL_VERSION', 'ACTUAL_DATASET_ID', 'IMAGE_NAME',
#        'PREDICTED_DATASET_ID', 'CONFIDENCE', 'REQUEST_ID', 'MODEL_ID',
#        'MODEL_NAME', 'TYPE', 'ACTUAL_IMAGE', 'PREDICTED_IMAGE', 'MATCH'],
#       dtype='object')
#
# Data Types:
# MODEL_VERSION            int64
# ACTUAL_DATASET_ID        int64
# IMAGE_NAME              object
# PREDICTED_DATASET_ID     int64
# CONFIDENCE               int64
# REQUEST_ID              object
# MODEL_ID                 int64
# MODEL_NAME              object
# TYPE                    object
# ACTUAL_IMAGE            object
# PREDICTED_IMAGE         object
# MATCH                   object
# dtype: object

# %%
# Convert numerical columns into proper data types
df['MODEL_VERSION'] = df['MODEL_VERSION'].astype('Int64')
df['ACTUAL_DATASET_ID'] = df['ACTUAL_DATASET_ID'].astype('Int64')
df['PREDICTED_DATASET_ID'] = df['PREDICTED_DATASET_ID'].astype('Int64')
df['CONFIDENCE'] = df['CONFIDENCE'].astype('Int64')
df['MODEL_ID'] = df['MODEL_ID'].astype('Int64')

# Display the data types to confirm the conversion
print(df.dtypes)
# Out:
# MODEL_VERSION            Int64
# ACTUAL_DATASET_ID        Int64
# IMAGE_NAME              object
# PREDICTED_DATASET_ID     Int64
# CONFIDENCE               Int64
# REQUEST_ID              object
# MODEL_ID                 Int64
# MODEL_NAME              object
# TYPE                    object
# ACTUAL_IMAGE            object
# PREDICTED_IMAGE         object
# MATCH                   object
# dtype: object

# %% [markdown]
# ##### Distinct Values within Variables

# %%
# Group by 'model_name' and aggregate 'model_version' using set to get distinct values
distinct_versions = merged_df.groupby('MODEL_NAME')['MODEL_VERSION'].agg(lambda x: set(x))

# Print distinct model_version values for each model_name
for model_name, versions in distinct_versions.items():
    print(f"Model Name: {model_name}")
    print(f"Distinct Model Versions: {versions}\n")
# Out:
# Model Name: N1000_FileSet1_Chestxray_Model
# Distinct Model Versions: {368, 369, 370, 371, 373, 376}
#
# Model Name: N250_FileSet1_Chestxray_Model
# Distinct Model Versions: {451, 453, 456, 436, 439, 442}
#
# Model Name: N500_FileSet1_Chestxray_Model
# Distinct Model Versions: {480, 481, 290, 292, 293, 294}

# %%
# Group by 'model_name' and aggregate 'model_version' using set to get distinct values
distinct_versions = merged_df.groupby('MODEL_NAME')['MODEL_ID'].agg(lambda x: set(x))

# Print distinct model_version values for each model_name
for model_name, versions in distinct_versions.items():
    print(f"Model Name: {model_name}")
    print(f"Distinct Model IDs: {versions}\n")
# Out:
# Model Name: N1000_FileSet1_Chestxray_Model
# Distinct Model IDs: {936}
#
# Model Name: N250_FileSet1_Chestxray_Model
# Distinct Model IDs: {952}
#
# Model Name: N500_FileSet1_Chestxray_Model
# Distinct Model IDs: {933}

# %%
# Iterate over columns
for col in merged_df.columns:
    if merged_df[col].dtype == 'object':
        # Print column name and distinct values
        print(f"Column: {col}")
        print(merged_df[col].unique())
        print()
# Out:
# Column: IMAGE_NAME
# ['person147_bacteria_706.jpeg' 'person100_bacteria_482.jpeg'
#  'person78_bacteria_382.jpeg' 'person124_bacteria_589.jpeg'
#  'person1647_virus_2848.jpeg' 'person1675_virus_2891.jpeg'
#  'person89_bacteria_440.jpeg' 'person35_virus_80.jpeg'
#  'person122_bacteria_582.jpeg' 'person119_bacteria_565.jpeg'
#  'person1662_virus_2875.jpeg' 'person85_bacteria_422.jpeg'
#  'person1669_virus_2884.jpeg' 'person39_virus_85.jpeg'
#  'person36_virus_81.jpeg' 'person134_bacteria_640.jpeg'
#  'person138_bacteria_659.jpeg' 'person92_bacteria_450.jpeg'
#  'person34_virus_76.jpeg' 'person22_virus_55.jpeg'
#  'person120_bacteria_571.jpeg' 'person110_bacteria_531.jpeg'
#  'person23_virus_56.jpeg' 'person94_bacteria_457.jpeg'
#  'person126_bacteria_599.jpeg' 'person1_virus_13.jpeg'
#  'person151_bacteria_718.jpeg' 'person37_virus_82.jpeg'
#  'person109_bacteria_527.jpeg' 'person117_bacteria_556.jpeg'
#  'person86_bacteria_429.jpeg' 'person100_bacteria_477.jpeg'
#  'person82_bacteria_404.jpeg' 'person108_bacteria_506.jpeg'
#  'person81_bacteria_395.jpeg' 'person161_bacteria_762.jpeg'
#  'person139_bacteria_662.jpeg' 'person83_bacteria_409.jpeg'
#  'person1665_virus_2878.jpeg' 'person61_virus_118.jpeg'
#  'person1_virus_7.jpeg' 'person136_bacteria_650.jpeg'
#  'person79_virus_148.jpeg' 'person150_bacteria_715.jpeg'
#  'person103_bacteria_489.jpeg' 'person113_bacteria_541.jpeg'
#  'person101_bacteria_483.jpeg' 'person127_bacteria_604.jpeg'
#  'person103_bacteria_488.jpeg' 'person46_virus_96.jpeg'
#  'person87_bacteria_433.jpeg' 'person1623_virus_2813.jpeg'
#  'person113_bacteria_540.jpeg' 'person71_virus_132.jpeg'
#  'person114_bacteria_546.jpeg' 'person1_virus_6.jpeg'
#  'person96_bacteria_466.jpeg' 'person174_bacteria_832.jpeg'
#  'person139_bacteria_663.jpeg' 'person119_bacteria_568.jpeg'
#  'person25_virus_59.jpeg' 'person152_bacteria_724.jpeg'
#  'person82_bacteria_405.jpeg' 'person108_bacteria_507.jpeg'
#  'person86_bacteria_428.jpeg' 'person74_virus_135.jpeg'
#  'person109_bacteria_526.jpeg' 'person117_bacteria_557.jpeg'
#  'person1628_virus_2821.jpeg' 'person1_virus_12.jpeg'
#  'person161_bacteria_759.jpeg' 'person124_bacteria_592.jpeg'
#  'person126_bacteria_598.jpeg' 'person1655_virus_2861.jpeg'
#  'person108_bacteria_511.jpeg' 'person47_virus_99.jpeg'
#  'person94_bacteria_456.jpeg' 'person1650_virus_2854.jpeg'
#  'person1615_virus_2801.jpeg' 'person83_bacteria_412.jpeg'
#  'person140_bacteria_668.jpeg' 'person22_virus_54.jpeg'
#  'person120_bacteria_570.jpeg' 'person134_bacteria_641.jpeg'
#  'person44_virus_94.jpeg' 'person138_bacteria_658.jpeg'
#  'person1610_virus_2793.jpeg' 'person92_bacteria_451.jpeg'
#  'person85_bacteria_423.jpeg' 'person1669_virus_2885.jpeg'
#  'person81_bacteria_398.jpeg' 'person122_bacteria_583.jpeg'
#  'person153_bacteria_725.jpeg' 'person147_bacteria_711.jpeg'
#  'person88_bacteria_437.jpeg' 'person99_bacteria_474.jpeg'
#  'person175_bacteria_833.jpeg' 'person144_bacteria_690.jpeg'
#  'person49_virus_101.jpeg' 'person85_bacteria_419.jpeg'
#  'person1668_virus_2882.jpeg' 'person147_bacteria_707.jpeg'
#  'person48_virus_100.jpeg' 'person111_bacteria_536.jpeg'
#  'person133_bacteria_637.jpeg' 'person141_bacteria_681.jpeg'
#  'person172_bacteria_828.jpeg' 'person121_bacteria_576.jpeg'
#  'person157_bacteria_739.jpeg' 'person135_bacteria_647.jpeg'
#  'person1657_virus_2864.jpeg' 'person1620_virus_2807.jpeg'
#  'person152_bacteria_723.jpeg' 'person141_bacteria_678.jpeg'
#  'person82_bacteria_402.jpeg' 'person130_bacteria_626.jpeg'
#  'person139_bacteria_664.jpeg' 'person145_bacteria_696.jpeg'
#  'person154_bacteria_728.jpeg' 'person159_bacteria_747.jpeg'
#  'person1678_virus_2895.jpeg' 'person20_virus_51.jpeg'
#  'person1631_virus_2826.jpeg' 'person87_bacteria_434.jpeg'
#  'person101_bacteria_485.jpeg' 'person127_bacteria_603.jpeg'
#  'person143_bacteria_687.jpeg' 'person3_virus_17.jpeg'
#  'person28_virus_62.jpeg' 'person72_virus_133.jpeg'
#  'person149_bacteria_713.jpeg' 'person21_virus_52.jpeg'
#  'person157_bacteria_735.jpeg' 'person91_bacteria_447.jpeg'
#  'person78_bacteria_384.jpeg' 'person175_bacteria_834.jpeg'
#  'person99_bacteria_473.jpeg' 'person155_bacteria_729.jpeg'
#  'person128_bacteria_607.jpeg' 'person80_bacteria_392.jpeg'
#  'person122_bacteria_584.jpeg' 'person85_bacteria_424.jpeg'
#  'person1676_virus_2892.jpeg' 'person43_virus_92.jpeg'
#  'person44_virus_93.jpeg' 'person1674_virus_2890.jpeg'
#  'person125_bacteria_594.jpeg' 'person109_bacteria_517.jpeg'
#  'person173_bacteria_829.jpeg' 'person1650_virus_2852.jpeg'
#  'person83_bacteria_414.jpeg' 'person69_virus_129.jpeg'
#  'person125_bacteria_595.jpeg' 'person1612_virus_2797.jpeg'
#  'person104_bacteria_492.jpeg' 'person1633_virus_2829.jpeg'
#  'person55_virus_110.jpeg' 'person59_virus_116.jpeg'
#  'person122_bacteria_585.jpeg' 'person80_bacteria_393.jpeg'
#  'person128_bacteria_606.jpeg' 'person62_virus_119.jpeg'
#  'person78_bacteria_385.jpeg' 'person175_bacteria_835.jpeg'
#  'person1651_virus_2855.jpeg' 'person91_bacteria_446.jpeg'
#  'person1614_virus_2800.jpeg' 'person66_virus_125.jpeg'
#  'person1616_virus_2802.jpeg' 'person21_virus_53.jpeg'
#  'person8_virus_28.jpeg' 'person3_virus_16.jpeg' 'person28_virus_63.jpeg'
#  'person127_bacteria_602.jpeg' 'person1656_virus_2862.jpeg'
#  'person76_virus_138.jpeg' 'person65_virus_123.jpeg'
#  'person146_bacteria_700.jpeg' 'person101_bacteria_484.jpeg'
#  'person118_bacteria_559.jpeg' 'person52_virus_106.jpeg'
#  'person77_virus_139.jpeg' 'person64_virus_122.jpeg'
#  'person159_bacteria_746.jpeg' 'person1640_virus_2839.jpeg'
#  'person139_bacteria_665.jpeg' 'person53_virus_107.jpeg'
#  'person19_virus_50.jpeg' 'person130_bacteria_627.jpeg'
#  'person152_bacteria_722.jpeg' 'person82_bacteria_403.jpeg'
#  'person11_virus_38.jpeg' 'person135_bacteria_646.jpeg'
#  'person1618_virus_2805.jpeg' 'person18_virus_49.jpeg'
#  'person80_bacteria_389.jpeg' 'person111_bacteria_537.jpeg'
#  'person142_bacteria_684.jpeg' 'person109_bacteria_519.jpeg'
#  'person146_bacteria_703.jpeg' 'person157_bacteria_740.jpeg'
#  'person136_bacteria_654.jpeg' 'person1673_virus_2889.jpeg'
#  'person1612_virus_2798.jpeg' 'person173_bacteria_831.jpeg'
#  'person1660_virus_2869.jpeg' 'person139_bacteria_666.jpeg'
#  'person1629_virus_2823.jpeg' 'person118_bacteria_560.jpeg'
#  'person152_bacteria_721.jpeg' 'person123_bacteria_587.jpeg'
#  'person131_bacteria_629.jpeg' 'person109_bacteria_523.jpeg'
#  'person91_bacteria_449.jpeg' 'person1653_virus_2858.jpeg'
#  'person155_bacteria_731.jpeg' 'person143_bacteria_689.jpeg'
#  'person1680_virus_2897.jpeg' 'person133_bacteria_635.jpeg'
#  'person111_bacteria_534.jpeg' 'person8_virus_27.jpeg'
#  'person1637_virus_2834.jpeg' 'person41_virus_88.jpeg'
#  'person1671_virus_2887.jpeg' 'person134_bacteria_644.jpeg'
#  'person104_bacteria_491.jpeg' 'person130_bacteria_628.jpeg'
#  'person53_virus_108.jpeg' 'person122_bacteria_586.jpeg'
#  'person63_virus_121.jpeg' 'person80_bacteria_390.jpeg'
#  'person141_bacteria_676.jpeg' 'person128_bacteria_605.jpeg'
#  'person1682_virus_2899.jpeg' 'person78_bacteria_386.jpeg'
#  'person158_bacteria_744.jpeg' 'person91_bacteria_445.jpeg'
#  'person50_virus_102.jpeg' 'person137_bacteria_655.jpeg'
#  'person1664_virus_2877.jpeg' 'person1663_virus_2876.jpeg'
#  'person42_virus_89.jpeg' 'person40_virus_87.jpeg' 'person3_virus_15.jpeg'
#  'person126_bacteria_600.jpeg' 'person121_bacteria_578.jpeg'
#  'person172_bacteria_827.jpeg' 'person121_bacteria_579.jpeg'
#  'person1649_virus_2850.jpeg' 'person133_bacteria_638.jpeg'
#  'person78_bacteria_387.jpeg' 'person158_bacteria_745.jpeg'
#  'person141_bacteria_677.jpeg' 'person121_bacteria_580.jpeg'
#  'person67_virus_126.jpeg' 'person80_bacteria_391.jpeg'
#  'person78_virus_140.jpeg' 'person1626_virus_2818.jpeg'
#  'person33_virus_72.jpeg' 'person1608_virus_2786.jpeg'
#  'person133_bacteria_634.jpeg' 'person111_bacteria_535.jpeg'
#  'person143_bacteria_688.jpeg' 'person1642_virus_2842.jpeg'
#  'person121_bacteria_575.jpeg' 'person30_virus_69.jpeg'
#  'person155_bacteria_730.jpeg' 'person1653_virus_2859.jpeg'
#  'person93_bacteria_454.jpeg' 'person38_virus_83.jpeg'
#  'person109_bacteria_522.jpeg' 'person91_bacteria_448.jpeg'
#  'person117_bacteria_553.jpeg' 'person1622_virus_2810.jpeg'
#  'person152_bacteria_720.jpeg' 'person128_bacteria_608.jpeg'
#  'person32_virus_71.jpeg' 'person130_bacteria_625.jpeg'
#  'person173_bacteria_830.jpeg' 'person10_virus_35.jpeg'
#  'person54_virus_109.jpeg' 'person1644_virus_2844.jpeg'
#  'person31_virus_70.jpeg' 'person1634_virus_2830.jpeg'
#  'person101_bacteria_486.jpeg' 'person112_bacteria_539.jpeg'
#  'person60_virus_117.jpeg' 'person132_bacteria_632.jpeg'
#  'person120_bacteria_573.jpeg' 'person109_bacteria_513.jpeg'
#  'person83_bacteria_411.jpeg' 'person136_bacteria_648.jpeg'
#  'person134_bacteria_642.jpeg' 'person1_virus_9.jpeg'
#  'person153_bacteria_726.jpeg' 'person119_bacteria_567.jpeg'
#  'person83_bacteria_407.jpeg' 'person100_bacteria_479.jpeg'
#  'person1670_virus_2886.jpeg' 'person141_bacteria_670.jpeg'
#  'person1661_virus_2872.jpeg' 'person78_bacteria_380.jpeg'
#  'person158_bacteria_742.jpeg' 'person1659_virus_2867.jpeg'
#  'person100_bacteria_480.jpeg' 'person51_virus_105.jpeg'
#  'person142_bacteria_682.jpeg' 'person140_bacteria_667.jpeg'
#  'person16_virus_47.jpeg' 'person113_bacteria_543.jpeg'
#  'person114_bacteria_545.jpeg' 'person71_virus_131.jpeg'
#  'person150_bacteria_717.jpeg' 'person138_bacteria_657.jpeg'
#  'person1641_virus_2840.jpeg' 'person136_bacteria_652.jpeg'
#  'person90_bacteria_442.jpeg' 'person96_bacteria_465.jpeg'
#  'person70_virus_130.jpeg' 'person1667_virus_2881.jpeg'
#  'person81_bacteria_397.jpeg' 'person108_bacteria_504.jpeg'
#  'person88_bacteria_438.jpeg' 'person100_bacteria_475.jpeg'
#  'person97_bacteria_468.jpeg' 'person38_virus_84.jpeg'
#  'person1628_virus_2822.jpeg' 'person1_virus_11.jpeg'
#  'person15_virus_46.jpeg' 'person93_bacteria_453.jpeg'
#  'person124_bacteria_591.jpeg' 'person1679_virus_2896.jpeg'
#  'person1613_virus_2799.jpeg' 'person1672_virus_2888.jpeg'
#  'person133_bacteria_633.jpeg' 'person17_virus_48.jpeg'
#  'person1632_virus_2827.jpeg' 'person102_bacteria_487.jpeg'
#  'person111_bacteria_533.jpeg' 'person1645_virus_2845.jpeg'
#  'person57_virus_113.jpeg' 'person85_bacteria_417.jpeg'
#  'person124_bacteria_590.jpeg' 'person75_virus_136.jpeg'
#  'person45_virus_95.jpeg' 'person95_bacteria_463.jpeg'
#  'person56_virus_112.jpeg' 'person1625_virus_2817.jpeg'
#  'person88_bacteria_439.jpeg' 'person1635_virus_2831.jpeg'
#  'person81_bacteria_396.jpeg' 'person130_bacteria_623.jpeg'
#  'person139_bacteria_661.jpeg' 'person1619_virus_2806.jpeg'
#  'person1643_virus_2843.jpeg' 'person96_bacteria_464.jpeg'
#  'person90_bacteria_443.jpeg' 'person114_bacteria_544.jpeg'
#  'person1685_virus_2903.jpeg' 'person150_bacteria_716.jpeg'
#  'person146_bacteria_704.jpeg' 'person113_bacteria_542.jpeg'
#  'person26_virus_60.jpeg' 'person29_virus_64.jpeg'
#  'person142_bacteria_683.jpeg' 'person100_bacteria_481.jpeg'
#  'person94_bacteria_458.jpeg' 'person147_bacteria_705.jpeg'
#  'person1627_virus_2819.jpeg' 'person78_bacteria_378.jpeg'
#  'person161_bacteria_757.jpeg' 'person109_bacteria_528.jpeg'
#  'person1661_virus_2873.jpeg' 'person78_bacteria_381.jpeg'
#  'person158_bacteria_743.jpeg' 'person24_virus_58.jpeg'
#  'person100_bacteria_478.jpeg' 'person119_bacteria_566.jpeg'
#  'person122_bacteria_581.jpeg' 'person85_bacteria_421.jpeg'
#  'person103_bacteria_490.jpeg' 'person1_virus_8.jpeg'
#  'person136_bacteria_649.jpeg' 'person134_bacteria_643.jpeg'
#  'person14_virus_44.jpeg' 'person120_bacteria_572.jpeg'
#  'person171_bacteria_826.jpeg' 'person109_bacteria_512.jpeg'
#  'person83_bacteria_410.jpeg' 'person112_bacteria_538.jpeg'
#  'IM-0031-0001.jpeg' 'IM-0025-0001.jpeg' 'NORMAL2-IM-0272-0001.jpeg'
#  'NORMAL2-IM-0102-0001.jpeg' 'NORMAL2-IM-0229-0001.jpeg'
#  'NORMAL2-IM-0315-0001.jpeg' 'NORMAL2-IM-0123-0001.jpeg'
#  'NORMAL2-IM-0301-0001.jpeg' 'NORMAL2-IM-0246-0001-0002.jpeg'
#  'IM-0010-0001.jpeg' 'IM-0046-0001.jpeg' 'NORMAL2-IM-0357-0001.jpeg'
#  'NORMAL2-IM-0027-0001.jpeg' 'NORMAL2-IM-0033-0001.jpeg'
#  'NORMAL2-IM-0343-0001.jpeg' 'IM-0028-0001.jpeg'
#  'NORMAL2-IM-0339-0001.jpeg' 'NORMAL2-IM-0173-0001-0002.jpeg'
#  'NORMAL2-IM-0012-0001.jpeg' 'NORMAL2-IM-0362-0001.jpeg'
#  'IM-0009-0001.jpeg' 'NORMAL2-IM-0297-0001.jpeg' 'IM-0073-0001.jpeg'
#  'IM-0067-0001.jpeg' 'NORMAL2-IM-0283-0001.jpeg'
#  'NORMAL2-IM-0376-0001.jpeg' 'NORMAL2-IM-0313-0001.jpeg'
#  'NORMAL2-IM-0019-0001.jpeg' 'NORMAL2-IM-0369-0001.jpeg'
#  'NORMAL2-IM-0196-0001.jpeg' 'IM-0016-0001.jpeg'
#  'NORMAL2-IM-0288-0001.jpeg' 'NORMAL2-IM-0241-0001.jpeg'
#  'IM-0011-0001-0001.jpeg' 'NORMAL2-IM-0131-0001.jpeg'
#  'NORMAL2-IM-0307-0001.jpeg' 'IM-0037-0001.jpeg'
#  'NORMAL2-IM-0326-0001.jpeg' 'NORMAL2-IM-0110-0001.jpeg'
#  'IM-0084-0001.jpeg' 'IM-0059-0001.jpeg' 'NORMAL2-IM-0332-0001.jpeg'
#  'NORMAL2-IM-0274-0001.jpeg' 'IM-0023-0001.jpeg'
#  'NORMAL2-IM-0348-0001.jpeg' 'NORMAL2-IM-0381-0001.jpeg'
#  'IM-0075-0001.jpeg' 'NORMAL2-IM-0364-0001.jpeg'
#  'NORMAL2-IM-0222-0001.jpeg' 'NORMAL2-IM-0370-0001.jpeg'
#  'NORMAL2-IM-0146-0001.jpeg' 'IM-0061-0001.jpeg'
#  'NORMAL2-IM-0285-0001.jpeg' 'NORMAL2-IM-0217-0001.jpeg'
#  'NORMAL2-IM-0351-0001.jpeg' 'IM-0089-0001.jpeg'
#  'NORMAL2-IM-0092-0001.jpeg' 'NORMAL2-IM-0279-0001.jpeg'
#  'NORMAL2-IM-0086-0001.jpeg' 'NORMAL2-IM-0345-0001.jpeg'
#  'NORMAL2-IM-0035-0001.jpeg' 'IM-0097-0001.jpeg'
#  'NORMAL2-IM-0335-0001.jpeg' 'NORMAL2-IM-0045-0001.jpeg'
#  'NORMAL2-IM-0273-0001.jpeg' 'NORMAL2-IM-0267-0001.jpeg'
#  'NORMAL2-IM-0051-0001.jpeg' 'NORMAL2-IM-0098-0001.jpeg'
#  'NORMAL2-IM-0321-0001.jpeg' 'NORMAL2-IM-0117-0001.jpeg'
#  'IM-0083-0001.jpeg' 'IM-0030-0001.jpeg' 'NORMAL2-IM-0246-0001.jpeg'
#  'NORMAL2-IM-0300-0001.jpeg' 'IM-0011-0001.jpeg' 'IM-0005-0001.jpeg'
#  'NORMAL2-IM-0252-0001.jpeg' 'IM-0029-0001.jpeg'
#  'NORMAL2-IM-0081-0001.jpeg' 'NORMAL2-IM-0338-0001.jpeg'
#  'IM-0101-0001.jpeg' 'NORMAL2-IM-0095-0001.jpeg'
#  'NORMAL2-IM-0210-0001.jpeg' 'NORMAL2-IM-0282-0001.jpeg'
#  'NORMAL2-IM-0007-0001.jpeg' 'NORMAL2-IM-0141-0001.jpeg'
#  'NORMAL2-IM-0013-0001.jpeg' 'NORMAL2-IM-0319-0001.jpeg'
#  'IM-0017-0001.jpeg' 'NORMAL2-IM-0130-0001.jpeg'
#  'NORMAL2-IM-0289-0001.jpeg' 'IM-0079-0001.jpeg'
#  'NORMAL2-IM-0312-0001.jpeg' 'IM-0003-0001.jpeg'
#  'NORMAL2-IM-0368-0001.jpeg' 'IM-0033-0001-0002.jpeg' 'IM-0091-0001.jpeg'
#  'NORMAL2-IM-0275-0001.jpeg' 'NORMAL2-IM-0374-0001-0001.jpeg'
#  'NORMAL2-IM-0105-0001.jpeg' 'NORMAL2-IM-0333-0001.jpeg'
#  'IM-0022-0001.jpeg' 'NORMAL2-IM-0349-0001.jpeg'
#  'NORMAL2-IM-0380-0001.jpeg' 'IM-0036-0001.jpeg'
#  'NORMAL2-IM-0327-0001.jpeg' 'NORMAL2-IM-0111-0001.jpeg'
#  'IM-0085-0001.jpeg' 'NORMAL2-IM-0237-0001.jpeg'
#  'NORMAL2-IM-0129-0001.jpeg' 'NORMAL2-IM-0259-0001.jpeg'
#  'NORMAL2-IM-0290-0001.jpeg' 'NORMAL2-IM-0278-0001.jpeg'
#  'NORMAL2-IM-0350-0001.jpeg' 'IM-0041-0001.jpeg' 'IM-0107-0001.jpeg'
#  'IM-0006-0001.jpeg' 'NORMAL2-IM-0251-0001.jpeg'
#  'NORMAL2-IM-0317-0001.jpeg' 'NORMAL2-IM-0135-0001.jpeg'
#  'NORMAL2-IM-0303-0001.jpeg' 'NORMAL2-IM-0073-0001.jpeg'
#  'IM-0049-0001.jpeg' 'NORMAL2-IM-0322-0001.jpeg'
#  'NORMAL2-IM-0052-0001.jpeg' 'IM-0033-0001.jpeg'
#  'NORMAL2-IM-0028-0001.jpeg' 'IM-0027-0001.jpeg'
#  'NORMAL2-IM-0336-0001.jpeg' 'NORMAL2-IM-0360-0001.jpeg'
#  'IM-0071-0001.jpeg' 'NORMAL2-IM-0281-0001.jpeg' 'IM-0065-0001.jpeg'
#  'NORMAL2-IM-0374-0001.jpeg' 'NORMAL2-IM-0232-0001.jpeg'
#  'NORMAL2-IM-0096-0001.jpeg' 'IM-0033-0001-0001.jpeg'
#  'NORMAL2-IM-0374-0001-0002.jpeg' 'IM-0102-0001.jpeg'
#  'NORMAL2-IM-0213-0001.jpeg' 'NORMAL2-IM-0207-0001.jpeg'
#  'NORMAL2-IM-0341-0001.jpeg' 'IM-0050-0001.jpeg' 'IM-0099-0001.jpeg'
#  'IM-0035-0001.jpeg' 'IM-0086-0001.jpeg' 'IM-0109-0001.jpeg'
#  'NORMAL2-IM-0112-0001.jpeg' 'NORMAL2-IM-0330-0001.jpeg'
#  'NORMAL2-IM-0276-0001.jpeg' 'IM-0021-0001.jpeg'
#  'NORMAL2-IM-0311-0001.jpeg' 'NORMAL2-IM-0305-0001.jpeg'
#  'NORMAL2-IM-0023-0001.jpeg' 'NORMAL2-IM-0353-0001.jpeg'
#  'NORMAL2-IM-0329-0001.jpeg' 'NORMAL2-IM-0059-0001.jpeg'
#  'IM-0110-0001.jpeg' 'NORMAL2-IM-0347-0001.jpeg'
#  'NORMAL2-IM-0171-0001.jpeg' 'NORMAL2-IM-0201-0001.jpeg'
#  'IM-0077-0001.jpeg' 'NORMAL2-IM-0150-0001.jpeg'
#  'NORMAL2-IM-0199-0001.jpeg' 'NORMAL2-IM-0366-0001.jpeg'
#  'NORMAL2-IM-0372-0001.jpeg' 'IM-0019-0001.jpeg'
#  'NORMAL2-IM-0287-0001.jpeg' 'IM-0063-0001.jpeg' 'IM-0069-0001.jpeg'
#  'NORMAL2-IM-0072-0001.jpeg' 'NORMAL2-IM-0302-0001.jpeg'
#  'IM-0013-0001.jpeg' 'NORMAL2-IM-0378-0001.jpeg' 'IM-0007-0001.jpeg'
#  'NORMAL2-IM-0316-0001.jpeg' 'NORMAL2-IM-0120-0001.jpeg'
#  'NORMAL2-IM-0066-0001.jpeg' 'NORMAL2-IM-0337-0001.jpeg'
#  'NORMAL2-IM-0271-0001.jpeg' 'IM-0095-0001.jpeg' 'IM-0081-0001.jpeg'
#  'NORMAL2-IM-0323-0001.jpeg' 'NORMAL2-IM-0359-0001.jpeg'
#  'NORMAL2-IM-0029-0001.jpeg' 'NORMAL2-IM-0139-0001.jpeg'
#  'NORMAL2-IM-0249-0001.jpeg' 'NORMAL2-IM-0280-0001.jpeg'
#  'NORMAL2-IM-0233-0001.jpeg' 'NORMAL2-IM-0361-0001.jpeg'
#  'IM-0011-0001-0002.jpeg' 'IM-0070-0001.jpeg' 'NORMAL2-IM-0294-0001.jpeg'
#  'NORMAL2-IM-0340-0001.jpeg' 'NORMAL2-IM-0206-0001.jpeg'
#  'NORMAL2-IM-0030-0001.jpeg' 'IM-0103-0001.jpeg' 'IM-0045-0001.jpeg'
#  'NORMAL2-IM-0354-0001.jpeg' 'NORMAL2-IM-0041-0001.jpeg'
#  'NORMAL2-IM-0277-0001.jpeg' 'NORMAL2-IM-0107-0001.jpeg'
#  'NORMAL2-IM-0331-0001.jpeg' 'IM-0093-0001.jpeg'
#  'NORMAL2-IM-0219-0001.jpeg' 'IM-0087-0001.jpeg'
#  'NORMAL2-IM-0173-0001-0001.jpeg' 'NORMAL2-IM-0325-0001.jpeg'
#  'IM-0015-0001.jpeg' 'NORMAL2-IM-0238-0001.jpeg'
#  'NORMAL2-IM-0132-0001.jpeg' 'NORMAL2-IM-0304-0001.jpeg'
#  'NORMAL2-IM-0256-0001.jpeg' 'NORMAL2-IM-0060-0001.jpeg'
#  'NORMAL2-IM-0310-0001.jpeg' 'NORMAL2-IM-0195-0001.jpeg'
#  'IM-0001-0001.jpeg' 'IM-0111-0001.jpeg' 'NORMAL2-IM-0346-0001.jpeg'
#  'NORMAL2-IM-0352-0001.jpeg' 'IM-0039-0001.jpeg'
#  'NORMAL2-IM-0058-0001.jpeg' 'NORMAL2-IM-0328-0001.jpeg'
#  'IM-0043-0001.jpeg' 'IM-0105-0001.jpeg' 'NORMAL2-IM-0373-0001.jpeg'
#  'NORMAL2-IM-0145-0001.jpeg' 'NORMAL2-IM-0286-0001.jpeg'
#  'NORMAL2-IM-0079-0001.jpeg' 'NORMAL2-IM-0309-0001.jpeg'
#  'NORMAL2-IM-0246-0001-0001.jpeg' 'NORMAL2-IM-0292-0001.jpeg'
#  'NORMAL2-IM-0221-0001.jpeg' 'NORMAL2-IM-0198-0001.jpeg']
#
# Column: REQUEST_ID
# ['FinalDataset1089_Version373_FINAL_PneumoniaClassification_Testing_1_PNEUMONIA_ALL_person147_bacteria_706'
#  'FinalDataset1089_Version373_FINAL_PneumoniaClassification_Testing_1_PNEUMONIA_ALL_person100_bacteria_482'
#  'FinalDataset1089_Version373_FINAL_PneumoniaClassification_Testing_1_PNEUMONIA_ALL_person78_bacteria_382'
#  ...
#  'FinalDataset1167_Version439_FINAL_PneumoniaClassification_Testing_1_NORMAL_ALL_NORMAL2-IM-0292-0001'
#  'FinalDataset1167_Version439_FINAL_PneumoniaClassification_Testing_1_NORMAL_ALL_NORMAL2-IM-0221-0001'
#  'FinalDataset1167_Version439_FINAL_PneumoniaClassification_Testing_1_NORMAL_ALL_NORMAL2-IM-0198-0001']
#
# Column: MODEL_NAME
# ['N1000_FileSet1_Chestxray_Model' 'N500_FileSet1_Chestxray_Model'
#  'N250_FileSet1_Chestxray_Model']
#
# Column: TYPE
# ['Classification']
#
# Column: ACTUAL_IMAGE
# ['PNEUMONIA' 'NORMAL']
#
# Column: PREDICTED_IMAGE
# ['PNEUMONIA' 'NORMAL' 'None']
#
# Column: MATCH
# ['YES' 'NO']

# %%
# Print distinct MODEL_VERSION values
print("Distinct MODEL_VERSION values:")
print(merged_df["MODEL_VERSION"].unique())
# Out:
# Distinct MODEL_VERSION values:
# [373 376 370 371 368 369 480 481 292 294 290 293 453 456 442 451 436 439]

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Create New Variables

# %%
# Create a new variable DATASET_SIZE using MODEL_ID column
# Mapping dictionary for MODEL_ID to DATA_SIZE
data_size_mapping = {
    936: 2000,
    933: 1000,
    952: 500,
}

# Create new variable DATA_SIZE based on MODEL_ID
merged_df['DATA_SIZE'] = merged_df['MODEL_ID'].map(data_size_mapping)

# Print the first few rows to verify the result
print(merged_df[['MODEL_ID', 'DATA_SIZE']])
# Out:
#        MODEL_ID  DATA_SIZE
# 0           936       2000
# 1           936       2000
# 2           936       2000
# 3           936       2000
# 4           936       2000
# ...         ...        ...
# 11227       952        500
# 11228       952        500
# 11229       952        500
# 11230       952        500
# 11231       952        500
#
# [11232 rows x 2 columns]

# %%
# Create a new variable CNN_MODEL  and add values as follows using MODEL_VERSION column
# Mapping dictionary for MODEL_VERSION to CNN_MODEL
cnn_model_mapping = {
    373: 'InceptionV3',
    376: 'InceptionV3',
    370: 'ResNet50',
    371: 'ResNet50',
    368: 'ResNet18',
    369: 'ResNet18',
    480: 'InceptionV3',
    481: 'InceptionV3',
    292: 'ResNet50',
    294: 'ResNet50',
    290: 'ResNet18',
    293: 'ResNet18',
    453: 'InceptionV3',
    456: 'InceptionV3',
    442: 'ResNet50',
    451: 'ResNet50',
    436: 'ResNet18',
    439: 'ResNet18'
}

# Create new variable CNN_MODEL based on MODEL_VERSION
merged_df['CNN_MODEL'] = merged_df['MODEL_VERSION'].map(cnn_model_mapping)

# Print the first few rows to verify the result
print(merged_df[['MODEL_VERSION', 'CNN_MODEL']].head())
# Out:
#    MODEL_VERSION    CNN_MODEL
# 0            373  InceptionV3
# 1            373  InceptionV3
# 2            373  InceptionV3
# 3            373  InceptionV3
# 4            373  InceptionV3

# %%
# Create a new variable EPOCH  and add values as follows using MODEL_VERSION column
# Mapping dictionary for MODEL_VERSION to EPOCH
epoch_mapping = {
    373: '20',
    376: '50',
    370: '20',
    371: '50',
    368: '20',
    369: '50',
    480: '20',
    481: '50',
    292: '20',
    294: '50',
    290: '20',
    293: '50',
    453: '20',
    456: '50',
    442: '20',
    451: '50',
    436: '20',
    439: '50'
}

# Create new variable EPOCH based on MODEL_VERSION
merged_df['EPOCH'] = merged_df['MODEL_VERSION'].map(epoch_mapping)

# Print the first few rows to verify the result
print(merged_df[['MODEL_VERSION', 'EPOCH']].head())
# Out:
#    MODEL_VERSION EPOCH
# 0            373    20
# 1            373    20
# 2            373    20
# 3            373    20
# 4            373    20

# %%
merged_df.head
# Out:
# <bound method NDFrame.head of        MODEL_VERSION  ACTUAL_DATASET_ID                      IMAGE_NAME  \
# 0                373               1089     person147_bacteria_706.jpeg
# 1                373               1089     person100_bacteria_482.jpeg
# 2                373               1089      person78_bacteria_382.jpeg
# 3                373               1089     person124_bacteria_589.jpeg
# 4                373               1089      person1647_virus_2848.jpeg
# ...              ...                ...                             ...
# 11227            439               1167       NORMAL2-IM-0309-0001.jpeg
# 11228            439               1167  NORMAL2-IM-0246-0001-0001.jpeg
# 11229            439               1167       NORMAL2-IM-0292-0001.jpeg
# 11230            439               1167       NORMAL2-IM-0221-0001.jpeg
# 11231            439               1167       NORMAL2-IM-0198-0001.jpeg
#
#        PREDICTED_DATASET_ID  CONFIDENCE  \
# 0                      1089          99
# 1                      1089          99
# 2                      1089          99
# 3                      1089          99
# 4                      1089          99
# ...                     ...         ...
# 11227                  1167          91
# 11228                  1170          96
# 11229                  1170          79
# 11230                  1170          98
# 11231                  1170          97
#
#                                               REQUEST_ID  MODEL_ID  \
# 0      FinalDataset1089_Version373_FINAL_PneumoniaCla...       936
# 1      FinalDataset1089_Version373_FINAL_PneumoniaCla...       936
# 2      FinalDataset1089_Version373_FINAL_PneumoniaCla...       936
# 3      FinalDataset1089_Version373_FINAL_PneumoniaCla...       936
# 4      FinalDataset1089_Version373_FINAL_PneumoniaCla...       936
# ...                                                  ...       ...
# 11227  FinalDataset1167_Version439_FINAL_PneumoniaCla...       952
# 11228  FinalDataset1167_Version439_FINAL_PneumoniaCla...       952
# 11229  FinalDataset1167_Version439_FINAL_PneumoniaCla...       952
# 11230  FinalDataset1167_Version439_FINAL_PneumoniaCla...       952
# 11231  FinalDataset1167_Version439_FINAL_PneumoniaCla...       952
#
#                            MODEL_NAME            TYPE ACTUAL_IMAGE  \
# 0      N1000_FileSet1_Chestxray_Model  Classification    PNEUMONIA
# 1      N1000_FileSet1_Chestxray_Model  Classification    PNEUMONIA
# 2      N1000_FileSet1_Chestxray_Model  Classification    PNEUMONIA
# 3      N1000_FileSet1_Chestxray_Model  Classification    PNEUMONIA
# 4      N1000_FileSet1_Chestxray_Model  Classification    PNEUMONIA
# ...                               ...             ...          ...
# 11227   N250_FileSet1_Chestxray_Model  Classification       NORMAL
# 11228   N250_FileSet1_Chestxray_Model  Classification       NORMAL
# 11229   N250_FileSet1_Chestxray_Model  Classification       NORMAL
# 11230   N250_FileSet1_Chestxray_Model  Classification       NORMAL
# 11231   N250_FileSet1_Chestxray_Model  Classification       NORMAL
#
#       PREDICTED_IMAGE MATCH  DATA_SIZE    CNN_MODEL EPOCH
# 0           PNEUMONIA   YES       2000  InceptionV3    20
# 1           PNEUMONIA   YES       2000  InceptionV3    20
# 2           PNEUMONIA   YES       2000  InceptionV3    20
# 3           PNEUMONIA   YES       2000  InceptionV3    20
# 4           PNEUMONIA   YES       2000  InceptionV3    20
# ...               ...   ...        ...          ...   ...
# 11227          NORMAL   YES        500     ResNet18    50
# 11228       PNEUMONIA    NO        500     ResNet18    50
# 11229       PNEUMONIA    NO        500     ResNet18    50
# 11230       PNEUMONIA    NO        500     ResNet18    50
# 11231       PNEUMONIA    NO        500     ResNet18    50
#
# [11232 rows x 15 columns]>

# %%
# Iterate over columns and print each column name vertically
for col in merged_df.columns:
    print(col)
# Out:
# MODEL_VERSION
# ACTUAL_DATASET_ID
# IMAGE_NAME
# PREDICTED_DATASET_ID
# CONFIDENCE
# REQUEST_ID
# MODEL_ID
# MODEL_NAME
# TYPE
# ACTUAL_IMAGE
# PREDICTED_IMAGE
# MATCH
# DATA_SIZE
# CNN_MODEL
# EPOCH

# %%
# Save the new dataset
# Specify the file path
file_path = 'Pnemonia_interference.xlsx'

# Save the DataFrame as an Excel file
merged_df.to_excel(file_path, index=False)

print(f"DataFrame saved as '{file_path}'")
# Out:
# DataFrame saved as 'Pnemonia_interference.xlsx'

# %% [markdown]
# ## Model Performance Comparison

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Testing Accuracy Comparison

# %%
# Calculate accuracy
merged_df['ACCURACY'] = (merged_df['MATCH'] == 'YES').astype(int)

# %% [markdown]
# #### Testing Accuracy by CNN Model

# %%
# Check class distribution of CNN MODEL in the resampled dataset
cnn_counts = merged_df['CNN_MODEL'].value_counts()
print(cnn_counts)

# Plot the class distribution
plt.figure(figsize=(10, 6))
sns.barplot(x=cnn_counts.index, y=cnn_counts.values)
plt.title('Class Distribution of CNN_MODEL')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()
# Out:
# InceptionV3    3744
# ResNet50       3744
# ResNet18       3744
# Name: CNN_MODEL, dtype: int64

# %%
# Model Performance Comparison
plt.figure(figsize=(10, 6))
sns.barplot(x='CNN_MODEL', y='ACCURACY', data=merged_df)

plt.title('Model Performance Comparison by CNN Model')
plt.xlabel('CNN Model')
plt.ylabel('Accuracy')

# Add labels for each bar
for p in plt.gca().patches:
    height = p.get_height()
    plt.text(p.get_x() + p.get_width() / 2, height / 2 , f'{height:.3f}', ha='center')

plt.show()

# %% [markdown]
# #### Testing Accuracy by CNN Model and Epoch

# %%
# Count the occurrences of each epoch
epoch_counts = merged_df['EPOCH'].value_counts()

print(epoch_counts)

# Plot the class distribution
plt.figure(figsize=(8, 6))
sns.barplot(x=epoch_counts.index, y=epoch_counts.values)
plt.title('Distribution of EPOCH')
plt.xlabel('Epoch')
plt.ylabel('Count')
plt.show()
# Out:
# 20    5616
# 50    5616
# Name: EPOCH, dtype: int64

# %%
# Model Performance Comparison
plt.figure(figsize=(10, 6))
sns.barplot(x='CNN_MODEL', y='ACCURACY', hue='EPOCH', data=merged_df)

plt.title('Model Performance Comparison by Epoch')
plt.xlabel('CNN Model')
plt.ylabel('Accuracy')

# Add labels for each bar
for p in plt.gca().patches:
    height = p.get_height()
    plt.text(p.get_x() + p.get_width() / 2, height / 2 , f'{height:.3f}', ha='center')

plt.legend(title='Epoch', loc='lower right', bbox_to_anchor=(1, 0))

plt.show()

# %% [markdown]
# #### Testing Accuracy by Data Size and CNN Model

# %%
# Count the occurrences of each cnn_model
data_counts = merged_df['DATA_SIZE'].value_counts()
print(data_counts)

# Plot the class distribution
plt.figure(figsize=(8, 6))
sns.barplot(x=data_counts.index, y=data_counts.values)
plt.title('Distribution of DATA_SIZE')
plt.xlabel('DATA_SIZE')
plt.ylabel('Count')
plt.show()
# Out:
# 2000    3744
# 1000    3744
# 500     3744
# Name: DATA_SIZE, dtype: int64

# %%
# import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'merged_df'
plt.figure(figsize=(10, 6))
sns.barplot(x='CNN_MODEL', y='ACCURACY', hue='DATA_SIZE', data=merged_df)

plt.title('Model Performance Comparison by Dataset Size')
plt.xlabel('CNN Model')
plt.ylabel('Accuracy')

# Add labels for each bar
for p in plt.gca().patches:
    height = p.get_height()
    plt.text(p.get_x() + p.get_width() / 2, height / 2 , f'{height:.3f}', ha='center')

plt.legend(title='Data Size', loc='lower right', bbox_to_anchor=(1, 0))

plt.show()

# %% [markdown]
# #### Testing Accuracy by Data Size, Epoch and CNN Model

# %%
# Create two separate plots for each epoch
for epoch in merged_df['EPOCH'].unique():
    plt.figure(figsize=(12, 8))
    sns.barplot(x='CNN_MODEL', y='ACCURACY', hue='DATA_SIZE', 
                data=merged_df[merged_df['EPOCH'] == epoch])

    plt.title(f'Model Performance Comparison by Data Size (Epoch {epoch})')
    plt.xlabel('CNN Model')
    plt.ylabel('Accuracy')

    # Add labels for each bar
    for p in plt.gca().patches:
        height = p.get_height()
        plt.text(p.get_x() + p.get_width() / 2, height /2, f'{height:.3f}', ha='center')

    plt.legend(title='Data Size', loc='lower right', bbox_to_anchor=(1, 0))

    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming merged_df is your DataFrame

# Get unique epochs
epochs = merged_df['EPOCH'].unique()

# Create subplots with 1 row and 2 columns
fig, axs = plt.subplots(1, 2, figsize=(24, 8))

for i, epoch in enumerate(epochs):
    ax = axs[i]
    sns.barplot(x='CNN_MODEL', y='ACCURACY', hue='DATA_SIZE',
                data=merged_df[merged_df['EPOCH'] == epoch], ax=ax)

    ax.set_title(f'Model Performance Comparison by Data Size (Epoch {epoch})')
    ax.set_xlabel('CNN Model')
    ax.set_ylabel('Accuracy')

    # Add labels for each bar
    for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x() + p.get_width() / 2, height / 2, f'{height:.3f}', ha='center')

    ax.legend(title='Data Size', loc='lower right', bbox_to_anchor=(1, 0))

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Model Confidence Analysis

# %%
# Model Confidence Analysis
sns.boxplot(x='CNN_MODEL', y='CONFIDENCE', hue='MATCH', data=merged_df)
plt.title('Model Confidence Analysis')
plt.xlabel('CNN Model')
plt.ylabel('Confidence')
plt.show()

# %% [markdown]
# ### Error Analysis

# %% [markdown]
# ##### Create a Subset of the Data

# %%
# Create a subset of the data
subset_df = merged_df[['IMAGE_NAME', 'ACTUAL_IMAGE', 'CNN_MODEL', 'MATCH']]

# Print the first few rows of the subset for verification
print(subset_df.head())
# Out:
#                     IMAGE_NAME ACTUAL_IMAGE    CNN_MODEL MATCH
# 0  person147_bacteria_706.jpeg    PNEUMONIA  InceptionV3   YES
# 1  person100_bacteria_482.jpeg    PNEUMONIA  InceptionV3   YES
# 2   person78_bacteria_382.jpeg    PNEUMONIA  InceptionV3   YES
# 3  person124_bacteria_589.jpeg    PNEUMONIA  InceptionV3   YES
# 4   person1647_virus_2848.jpeg    PNEUMONIA  InceptionV3   YES

# %%
# Get the size of the dataset (number of rows and columns)
num_rows, num_cols = subset_df.shape
print(f"Number of rows in the dataset: {num_rows}")
print(f"Number of columns in the dataset: {num_cols}")
# Out:
# Number of rows in the dataset: 11232
# Number of columns in the dataset: 4

# %% [markdown]
# #### Error Analysis by CNN Model

# %%
# Error Analysis
error_df_cnn = subset_df[subset_df['MATCH'] == 'NO']
sns.countplot(x='CNN_MODEL', data=error_df_cnn)
plt.title('Error Analysis by CNN Model')
plt.xlabel('CNN Model')
plt.ylabel('Count')
plt.show()

# %%
# Calculate the total count of predictions for each model
total_predictions = subset_df['CNN_MODEL'].value_counts()

# Calculate the total count of errors for each model
error_counts = error_df_cnn['CNN_MODEL'].value_counts()

# Calculate the percentage of errors within each model
error_percentages = (error_counts / total_predictions) * 100

# Plot the error count and percentage
plt.figure(figsize=(10, 6))
sns.barplot(x=error_percentages.index, y=error_percentages.values)
plt.title('Error Analysis by CNN Model')
plt.xlabel('CNN Model')
plt.ylabel('Error Percentage')


# Add labels for each class
for i, patch in enumerate(plt.gca().patches):
    height = patch.get_height()
    if height > 0:
        plt.text(patch.get_x() + patch.get_width() / 2, patch.get_y() + height /2,
                 f"{height:.1f}%", ha='center', va='center', color='black', fontsize=10)
        
plt.show()

# %% [markdown]
# #### Error Analysis by Class and CNN Model

# %% [markdown]
# ##### Check Class Distribution

# %%
# Count the occurrences of each class
class_counts = subset_df['ACTUAL_IMAGE'].value_counts()

# Plot the class distribution
plt.figure(figsize=(8, 6))
sns.barplot(x=class_counts.index, y=class_counts.values)
plt.title('Class Distribution of ACTUAL_IMAGE')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
# Error Analysis
error_df = subset_df[subset_df['MATCH'] == 'NO']
sns.countplot(x='CNN_MODEL', hue='ACTUAL_IMAGE', data=error_df)
plt.title('Error Analysis by CNN Model and Actual Image (Balanced Classes)')
plt.xlabel('CNN Model')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### Normalize the Chart Using Percentages

# %%
# Count the errors in each class within each CNN model
error_count = error_df.groupby(['CNN_MODEL', 'ACTUAL_IMAGE']).size().reset_index(name='ERROR_COUNT')

# Calculate the total errors for each CNN model
total_errors = error_count.groupby('CNN_MODEL')['ERROR_COUNT'].transform('sum')

# Calculate the percentage of errors in each class within each CNN model
error_count['ERROR_PERCENTAGE'] = (error_count['ERROR_COUNT'] / total_errors) * 100

# Create the barplot
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='CNN_MODEL', y='ERROR_PERCENTAGE', hue='ACTUAL_IMAGE', data=error_count)

# Add labels to each bar
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.5, f'{height:.2f}%', ha='center')

plt.title('Error Analysis by CNN Model & Class (Balanced Classes)')
plt.xlabel('CNN Model')
plt.ylabel('Error Percentage')
plt.show()
